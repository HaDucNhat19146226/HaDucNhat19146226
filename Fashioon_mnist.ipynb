# %%
import numpy as np 
from keras.utils import np_utils 
from keras.datasets import fashion_mnist
from keras.models import Sequential 
from keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import RMSprop 
import matplotlib.pyplot as plt

# %%
(x_train, y_train),(x_test,y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 1s 0us/step
# 26435584/26421880 [==============================] - 1s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %%
for i in range (9):
  plt.subplot(330 +i +1)
  plt.imshow(x_train[i],cmap=plt.get_cmap('gray'))
plt.show()

# %%
x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /=255
x_test /=255
y_train = np_utils.to_categorical(y_train,10)
y_test = np_utils.to_categorical(y_test,10)

# %%
model = Sequential()
model.add(Dense(512,activation='relu',input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 512)               262656
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 932,362
# Trainable params: 932,362
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer=RMSprop(), metrics=['accuracy'])
from keras.callbacks import EarlyStopping
history = model.fit(x_train,y_train,batch_size=128,epochs=500,verbose=1,
                    validation_split=0.2,callbacks=[EarlyStopping(monitor='val_loss',patience=70)])
# Out:
# Epoch 1/500
# 375/375 [==============================] - 8s 5ms/step - loss: 0.6188 - accuracy: 0.7755 - val_loss: 0.4087 - val_accuracy: 0.8494
# Epoch 2/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4385 - accuracy: 0.8401 - val_loss: 0.3630 - val_accuracy: 0.8694
# Epoch 3/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3967 - accuracy: 0.8569 - val_loss: 0.3980 - val_accuracy: 0.8518
# Epoch 4/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3765 - accuracy: 0.8639 - val_loss: 0.3611 - val_accuracy: 0.8773
# Epoch 5/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3635 - accuracy: 0.8685 - val_loss: 0.3683 - val_accuracy: 0.8719
# Epoch 6/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3573 - accuracy: 0.8731 - val_loss: 0.3551 - val_accuracy: 0.8765
# Epoch 7/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3470 - accuracy: 0.8787 - val_loss: 0.4061 - val_accuracy: 0.8566
# Epoch 8/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3412 - accuracy: 0.8799 - val_loss: 0.3832 - val_accuracy: 0.8791
# Epoch 9/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3418 - accuracy: 0.8817 - val_loss: 0.3733 - val_accuracy: 0.8792
# Epoch 10/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3389 - accuracy: 0.8818 - val_loss: 0.3974 - val_accuracy: 0.8667
# Epoch 11/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3326 - accuracy: 0.8835 - val_loss: 0.3848 - val_accuracy: 0.8805
# Epoch 12/500
# 375/375 [==============================] - 2s 6ms/step - loss: 0.3275 - accuracy: 0.8864 - val_loss: 0.3792 - val_accuracy: 0.8799
# Epoch 13/500
# 375/375 [==============================] - 3s 9ms/step - loss: 0.3226 - accuracy: 0.8858 - val_loss: 0.3935 - val_accuracy: 0.8864
# Epoch 14/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3250 - accuracy: 0.8885 - val_loss: 0.3822 - val_accuracy: 0.8784
# Epoch 15/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3194 - accuracy: 0.8901 - val_loss: 0.4037 - val_accuracy: 0.8811
# Epoch 16/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3237 - accuracy: 0.8901 - val_loss: 0.3765 - val_accuracy: 0.8823
# Epoch 17/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3155 - accuracy: 0.8915 - val_loss: 0.3963 - val_accuracy: 0.8901
# Epoch 18/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3120 - accuracy: 0.8920 - val_loss: 0.4134 - val_accuracy: 0.8857
# Epoch 19/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3091 - accuracy: 0.8946 - val_loss: 0.4428 - val_accuracy: 0.8853
# Epoch 20/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3088 - accuracy: 0.8941 - val_loss: 0.4330 - val_accuracy: 0.8843
# Epoch 21/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3090 - accuracy: 0.8950 - val_loss: 0.4938 - val_accuracy: 0.8851
# Epoch 22/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3071 - accuracy: 0.8944 - val_loss: 0.5005 - val_accuracy: 0.8789
# Epoch 23/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3093 - accuracy: 0.8959 - val_loss: 0.4439 - val_accuracy: 0.8901
# Epoch 24/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3014 - accuracy: 0.8974 - val_loss: 0.4315 - val_accuracy: 0.8885
# Epoch 25/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3025 - accuracy: 0.8973 - val_loss: 0.4518 - val_accuracy: 0.8912
# Epoch 26/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3011 - accuracy: 0.8982 - val_loss: 0.4544 - val_accuracy: 0.8874
# Epoch 27/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3025 - accuracy: 0.9016 - val_loss: 0.4615 - val_accuracy: 0.8891
# Epoch 28/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2956 - accuracy: 0.9001 - val_loss: 0.5007 - val_accuracy: 0.8890
# Epoch 29/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2996 - accuracy: 0.8999 - val_loss: 0.5697 - val_accuracy: 0.8892
# Epoch 30/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2957 - accuracy: 0.9018 - val_loss: 0.4832 - val_accuracy: 0.8898
# Epoch 31/500
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2960 - accuracy: 0.9031 - val_loss: 0.5096 - val_accuracy: 0.8853
# Epoch 32/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3091 - accuracy: 0.9013 - val_loss: 0.6013 - val_accuracy: 0.8845
# Epoch 33/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2934 - accuracy: 0.9020 - val_loss: 0.5388 - val_accuracy: 0.8903
# Epoch 34/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3061 - accuracy: 0.9023 - val_loss: 0.5793 - val_accuracy: 0.8863
# Epoch 35/500
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2871 - accuracy: 0.9049 - val_loss: 0.5779 - val_accuracy: 0.8814
# Epoch 36/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2872 - accuracy: 0.9053 - val_loss: 0.5932 - val_accuracy: 0.8873
# Epoch 37/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2948 - accuracy: 0.9052 - val_loss: 0.5235 - val_accuracy: 0.8922
# Epoch 38/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2925 - accuracy: 0.9053 - val_loss: 0.6597 - val_accuracy: 0.8788
# Epoch 39/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3009 - accuracy: 0.9049 - val_loss: 0.5897 - val_accuracy: 0.8907
# Epoch 40/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2956 - accuracy: 0.9056 - val_loss: 0.5437 - val_accuracy: 0.8839
# Epoch 41/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2851 - accuracy: 0.9062 - val_loss: 0.6106 - val_accuracy: 0.8817
# Epoch 42/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2892 - accuracy: 0.9069 - val_loss: 0.6174 - val_accuracy: 0.8864
# Epoch 43/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2920 - accuracy: 0.9078 - val_loss: 0.5582 - val_accuracy: 0.8898
# Epoch 44/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2939 - accuracy: 0.9049 - val_loss: 0.6335 - val_accuracy: 0.8818
# Epoch 45/500
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2973 - accuracy: 0.9069 - val_loss: 0.6198 - val_accuracy: 0.8696
# Epoch 46/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3067 - accuracy: 0.9091 - val_loss: 0.6546 - val_accuracy: 0.8913
# Epoch 47/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2805 - accuracy: 0.9111 - val_loss: 0.6520 - val_accuracy: 0.8898
# Epoch 48/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2843 - accuracy: 0.9084 - val_loss: 0.6266 - val_accuracy: 0.8887
# Epoch 49/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2884 - accuracy: 0.9077 - val_loss: 0.8194 - val_accuracy: 0.8927
# Epoch 50/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2852 - accuracy: 0.9089 - val_loss: 0.7057 - val_accuracy: 0.8942
# Epoch 51/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2903 - accuracy: 0.9081 - val_loss: 0.6736 - val_accuracy: 0.8930
# Epoch 52/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2803 - accuracy: 0.9093 - val_loss: 0.6624 - val_accuracy: 0.8897
# Epoch 53/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2858 - accuracy: 0.9102 - val_loss: 0.7262 - val_accuracy: 0.8922
# Epoch 54/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2712 - accuracy: 0.9100 - val_loss: 0.6791 - val_accuracy: 0.8832
# Epoch 55/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2826 - accuracy: 0.9112 - val_loss: 0.8650 - val_accuracy: 0.8874
# Epoch 56/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2831 - accuracy: 0.9126 - val_loss: 0.7916 - val_accuracy: 0.8965
# Epoch 57/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2789 - accuracy: 0.9137 - val_loss: 0.7728 - val_accuracy: 0.8871
# Epoch 58/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2819 - accuracy: 0.9112 - val_loss: 0.7877 - val_accuracy: 0.8959
# Epoch 59/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2769 - accuracy: 0.9130 - val_loss: 0.8252 - val_accuracy: 0.8932
# Epoch 60/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2750 - accuracy: 0.9126 - val_loss: 0.8048 - val_accuracy: 0.8972
# Epoch 61/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2739 - accuracy: 0.9136 - val_loss: 0.7909 - val_accuracy: 0.8967
# Epoch 62/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2771 - accuracy: 0.9161 - val_loss: 0.7033 - val_accuracy: 0.8892
# Epoch 63/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2854 - accuracy: 0.9143 - val_loss: 0.7219 - val_accuracy: 0.8930
# Epoch 64/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2727 - accuracy: 0.9157 - val_loss: 0.7563 - val_accuracy: 0.8852
# Epoch 65/500
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2729 - accuracy: 0.9158 - val_loss: 0.7328 - val_accuracy: 0.8927
# Epoch 66/500
# 375/375 [==============================] - 2s 6ms/step - loss: 0.2862 - accuracy: 0.9154 - val_loss: 0.6903 - val_accuracy: 0.8979
# Epoch 67/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2735 - accuracy: 0.9161 - val_loss: 0.7685 - val_accuracy: 0.8863
# Epoch 68/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2798 - accuracy: 0.9145 - val_loss: 0.7778 - val_accuracy: 0.8819
# Epoch 69/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2673 - accuracy: 0.9172 - val_loss: 0.8625 - val_accuracy: 0.8910
# Epoch 70/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2949 - accuracy: 0.9156 - val_loss: 0.7851 - val_accuracy: 0.8957
# Epoch 71/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2725 - accuracy: 0.9156 - val_loss: 0.7551 - val_accuracy: 0.8914
# Epoch 72/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2726 - accuracy: 0.9165 - val_loss: 0.7894 - val_accuracy: 0.8921
# Epoch 73/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2724 - accuracy: 0.9176 - val_loss: 0.7631 - val_accuracy: 0.8914
# Epoch 74/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2846 - accuracy: 0.9167 - val_loss: 0.9090 - val_accuracy: 0.8972
# Epoch 75/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2972 - accuracy: 0.9168 - val_loss: 0.8615 - val_accuracy: 0.8957
# Epoch 76/500
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2740 - accuracy: 0.9166 - val_loss: 0.9041 - val_accuracy: 0.8952

# %%
score = model.evaluate(x_test,y_test,verbose=0)
print('Test loss: ',score[0])
print('Test accuracy: ',score[1])
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()
# Out:
# Test loss:  1.1097204685211182
# Test accuracy:  0.8888999819755554
